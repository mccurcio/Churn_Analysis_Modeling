# %% [markdown]
# # AD&D Churn Analysis And Modeling
#
# To:&nbsp;&nbsp;&nbsp;&nbsp; [Magnimind](https://magnimindacademy.com/)
#
# From: Matt Curcio, matt.curcio.us@gmail.com
#
# Date: 2022-12-27
#
# Re:&nbsp;&nbsp;&nbsp; Churn Analysis, dates include 10/5/2022 to 11/5/2022
#
# ## EDA Pie Chart
#
# - **Accepted all columns as unchanged.**
# - Only columns 1 & 17 have skew >= 2.0.
# - This is ok since they are binary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as stats

# Load Cleaned Churn Data
df = pd.read_csv("../data/processed/mcc_clean_churn.csv")

# %%
labels = 'Exited', 'Retained'
sizes = [df.Churned[df['Churned']==1].count(), df.Churned[df['Churned']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(8, 8))
ax1.pie(sizes, 
        explode=explode, 
        labels=labels, 
        autopct='%1.0f%%',
        shadow=True, 
        startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained, ~1:7.", size = 20)

# Save the plot as an SVG file
fig1.savefig("../assets/Churn_piechart.svg", format="svg")

plt.show()
